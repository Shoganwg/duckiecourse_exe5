# %% [markdown]
# <img src="_media/dtlogo.png"/>

# %% [markdown]
# # Graphs tutorial
#
# In this activity we are going to explore how we can build, manipulate and search graphs.
#
# We use the [`networkx`][networkx] library for dealing with graphs.
#
# [networkx]: https://networkx.github.io

# %%
import networkx as nx

# %% [markdown]
# Another tutorial is available [here](https://networkx.github.io/documentation/stable/tutorial.html).

# %% [markdown]
# # Adding nodes and edges
#
# Use the class `MultiDiGraph` to create a directed graph with multiple edges and self-loops.

# %%
G = nx.DiGraph() # Directed
G = nx.MultiDiGraph()

# %% [markdown]
# Add nodes using `add_node`:

# %%
G.add_node('node1')
G.add_node('node2')
G.add_node('node3')

# %% [markdown]
# Check that a node is in the graph:

# %%
assert 'node1' in G

# %% [markdown]
# Get all nodes:

# %%
list(G.nodes())
# Out:
# ['node1', 'node2', 'node3']

# %% [markdown]
# Add some edges:

# %%
G.add_edge('node1', 'node2');

# %% [markdown]
# Nodes get automatically added:

# %%
G.add_edge('node2', 'another1');
G.add_edge('another1', 'another2');

# %% [markdown]
# List edges:

# %%
list(G.edges()) # list of 2-tuples (from, to)
# Out:
# [('node1', 'node2'), ('node2', 'another1'), ('another1', 'another2')]

# %%
for a,b in G.edges():
    print('edge from %s to %s' % (a, b))
    
list(G.nodes())
# Out:
# edge from node1 to node2
# edge from node2 to another1
# edge from another1 to another2
# ['node1', 'node2', 'node3', 'another1', 'another2']

# %% [markdown]
# ## Drawing graphs
#
# There are some minimal plotting capabilities.

# %%
def draw_graph(G0, pos=None):
    from matplotlib import pyplot as plt
    pos = pos or nx.spring_layout(G0)
    plt.figure(figsize=(12, 12))    
    nx.draw(G0,pos,labels={node:node for node in G0.nodes()})
    #nx.draw(G0,labels={node:node for node in G0.nodes()})
    def edge_label(a, b):
        datas = G0.get_edge_data(a, b)
        s = '%d edge%s' % (len(datas), 's' if len(datas)>=2 else '')
        for k, v in datas.items():
            if v:
                if 'label' in v:
                    s += '\n %s' % v['label']
                else:
                    s += '\n %s' %v
        return s
    edge_labels = dict([ ((a,b), edge_label(a,b)) for a,b in G0.edges()])
    nx.draw_networkx_edge_labels(G0,pos,edge_labels=edge_labels,font_color='red')
    plt.axis('off')
    plt.show()

# %%
draw_graph(G)

# %% [markdown]
# ## Multiple edges
#
# You can add a second edge between the nodes:

# %%
G.add_edge('node1', 'node2');

# %% [markdown]
# Notice now how there are two copies of the same edge:

# %%
list(G.edges())
# Out:
# [('node1', 'node2'),
#  ('node1', 'node2'),
#  ('node2', 'another1'),
#  ('another1', 'another2')]

# %% [markdown]
# Multiple edges in the graph:

# %%
draw_graph(G)

# %% [markdown]
# ## Attaching data to edges
#
# You can use the optional parameters of the `add_edge` method to attach some pieces of data.
#
# For example we add two more edges between `node1` and `node4` with property `prop` set to 12 and 15.

# %%
G.add_edge('node1', 'node4',  prop=12);
G.add_edge('node1', 'node4',  prop=15);

# %%
draw_graph(G)

# %% [markdown]
# Using the function `get_edge_data` we can get the data attached to the edge.
# The function returns a dictionary 'edge-label -> properties', where `edge-label` is just an integer.

# %%
data = G.get_edge_data('node1', 'node4');
print(data)
# Out:
# {0: {'prop': 12}, 1: {'prop': 15}}

# %%
for id_edge, edge_data in data.items():
    print('edge %s: attribute  prop = %s' % (id_edge, edge_data['prop']))
# Out:
# edge 0: attribute  prop = 12
# edge 1: attribute  prop = 15

# %% [markdown]
# ## Querying the graph
#
# Concepts:
#
# - neighbors: all nodes to which a node N connects
# - predecessors: all nodes connected to N
# - ancestors (transitive closure of predecessors)
# - successors
# - descendants (transitive closure of successors)

# %%
list(G.neighbors('node2'))
# Out:
# ['another1']

# %%
list(G.neighbors('another1'))
# Out:
# ['another2']

# %%
list(G.predecessors('node2'))
# Out:
# ['node1']

# %%
list(nx.ancestors(G, 'another2'))
# Out:
# ['node2', 'another1', 'node1']

# %%
list(G.successors('node2'))
# Out:
# ['another1']

# %%
list(nx.descendants(G, 'node2'))
# Out:
# ['another2', 'another1']

# %% [markdown]
# ## Cycles
#
# Use the function `nx.simple_cycles` to get the cycles in the graph:

# %%
list(nx.simple_cycles(G))
# Out:
# []

# %% [markdown]
# Let's create a more interesting graph:

# %%
G2 = nx.MultiDiGraph()
edges = [
    ('A', 'B'),
    ('B', 'C'),
    ('C', 'D'),
    ('D', 'E'),
    ('E', 'F'),
    ('F', 'A'),
    
    ('A', 'G'),
    ('G', 'H'),
    ('H', 'A')]
G2.add_edges_from(edges);

# %%
draw_graph(G2)

# %% [markdown]
# The function returns a list of lists:

# %%
list(nx.simple_cycles(G2))
# Out:
# [['H', 'A', 'G'], ['E', 'F', 'A', 'B', 'C', 'D']]

# %% [markdown]
# ## Paths
#
# Use `has_path` to check that two nodes are connected:

# %%
nx.has_path(G2, 'A', 'C')
# Out:
# True

# %%
nx.has_path(G2, 'C', 'A')
# Out:
# True

# %% [markdown]
# But what are these paths? Use `nx.shortest_path` to find out:

# %%
nx.shortest_path(G2, 'A', 'C')
# Out:
# ['A', 'B', 'C']

# %%
nx.shortest_path(G2, 'C', 'A')
# Out:
# ['C', 'D', 'E', 'F', 'A']

# %% [markdown]
# ## Attaching data to nodes
#
# Use kwargs of `add_node` to add attributes to nodes:

# %%
M = nx.DiGraph()
M.add_node('a', q=2)

# %% [markdown]
# Get it back using this syntax:

# %%
M.nodes['a']
# Out:
# {'q': 2}

# %% [markdown]
# ## Example: pose network
#
# We create a *pose network*: a graph where each node represents a pose
# and each edge is a measurement.
#
# Let's create a grid-like network:

# %%
H, W = 4, 4
grid_size = 0.61

# %%
# !pip install scipy
# !pip install PyGeometry
# !pip install PyGeometry-z6
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyGeometry-z6 in /usr/local/lib/python3.8/dist-packages (2.1.4)
# Requirement already satisfied: PyContracts3 in /usr/local/lib/python3.8/dist-packages (from PyGeometry-z6) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from PyGeometry-z6) (1.24.1)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from PyGeometry-z6) (1.3.3)
# Requirement already satisfied: zuper-commons-z6 in /usr/local/lib/python3.8/dist-packages (from PyGeometry-z6) (6.2.4)
# Requirement already satisfied: pyparsing in /usr/lib/python3/dist-packages (from PyContracts3->PyGeometry-z6) (2.4.6)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from PyContracts3->PyGeometry-z6) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from PyContracts3->PyGeometry-z6) (1.12.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from PyContracts3->PyGeometry-z6) (0.18.2)
# Requirement already satisfied: termcolor in /usr/lib/python3/dist-packages (from zuper-commons-z6->PyGeometry-z6) (1.1.0)
# Requirement already satisfied: webcolors in /usr/local/lib/python3.8/dist-packages (from zuper-commons-z6->PyGeometry-z6) (1.12)
# Requirement already satisfied: xtermcolor in /usr/local/lib/python3.8/dist-packages (from zuper-commons-z6->PyGeometry-z6) (1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from zuper-commons-z6->PyGeometry-z6) (2022.7)

# %%
import itertools

import numpy as np
np.typeDict = np.sctypeDict

import geometry as geo
M = nx.MultiDiGraph()
for i, j in itertools.product(range(H), range(W)):
    # node name is a tuple 
    node_name = (i, j)
    # create a pose 
    q = geo.SE2_from_translation_angle((i*grid_size, j*grid_size), 0)
    M.add_node(node_name, q=q) # q as property
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 7
#       4 np.typeDict = np.sctypeDict
#       6 import geometry as geo
# ----> 7 M = nx.MultiDiGraph()
#       8 for i, j in itertools.product(range(H), range(W)):
#       9     # node name is a tuple
#      10     node_name = (i, j)
#
# NameError: name 'nx' is not defined

# %%
# let's plot them where they are supposed to go
def position_for_node(node):
    # node is a tuple (i,j)
    # query the node properties
    properties = M.nodes[node]
    # get the pose set before
    q = properties['q']
    # extract the translation 
    t, _ = geo.translation_angle_from_SE2(q)
    # that's my position
    return t

pos = dict([(node, position_for_node(node)) for node in M])

draw_graph(M, pos=pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 13
#      10     # that's my position
#      11     return t
# ---> 13 pos = dict([(node, position_for_node(node)) for node in M])
#      15 draw_graph(M, pos=pos)
#
# Cell In[41], line 13, in <listcomp>(.0)
#      10     # that's my position
#      11     return t
# ---> 13 pos = dict([(node, position_for_node(node)) for node in M])
#      15 draw_graph(M, pos=pos)
#
# Cell In[41], line 9, in position_for_node(node)
#       7 q = properties['q']
#       8 # extract the translation
# ----> 9 t, _ = geo.translation_angle_from_SE2(q)
#      10 # that's my position
#      11 return t
#
# NameError: name 'geo' is not defined

# %% [markdown]
# Now let's create the network connections:

# %%
geo.SE2.friendly(geo.SE2.identity())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 geo.SE2.friendly(geo.SE2.identity())
#
# NameError: name 'geo' is not defined

# %%
for i, j in itertools.product(range(H), range(W)):
    # for each node
    
    # connect to neighbors
    for d in [ (+1, 0), (0, +1), (+1,+1)]:
        # neighbors coordinatex
        i2, j2 = i+d[0], j+d[1]
        # if neighbor exists
        if (i2,j2) in M:
            # add the connection
            
            # pose of the first node
            q1 = M.nodes[(i,j)]['q']
            # pose of the second node
            q2 = M.nodes[(i2,j2)]['q']
            # relative pose 
            relative_pose = geo.SE2.multiply(geo.SE2.inverse(q1), q2)
            # label 
            label = geo.SE2.friendly(relative_pose)
            # add the edge with two properties "label" and "relative_pose"
            M.add_edge( (i,j), (i2,j2), label=label, relative_pose=relative_pose)

# %%
draw_graph(M, pos=pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 draw_graph(M, pos=pos)
#
# NameError: name 'pos' is not defined

# %% [markdown]
# Now let's find the relative position between two nodes using the graph functions.

# %%
# let's add inverse edges 
for node1, node2 in M.edges():
    for id_edge, edge_data in M.get_edge_data(node1, node2).items():
        r = edge_data['relative_pose']
        rinv = geo.SE2.inverse(r)
        label = geo.SE2.friendly(rinv)
        M.add_edge(node2, node1, relative_pose=rinv, label=label)

# %%
draw_graph(M, pos=pos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 draw_graph(M, pos=pos)
#
# NameError: name 'pos' is not defined

# %%
node1, node2 = (1,3), (2,1)

# %%
path = nx.shortest_path(M, node1, node2)
print(path)
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 path = nx.shortest_path(M, node1, node2)
#       2 print(path)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/algorithms/shortest_paths/generic.py:165, in shortest_path(G, source, target, weight, method)
#     162 else:
#     163     # Find shortest source-target path.
#     164     if method == "unweighted":
# --> 165         paths = nx.bidirectional_shortest_path(G, source, target)
#     166     elif method == "dijkstra":
#     167         _, paths = nx.bidirectional_dijkstra(G, source, target, weight)
#
# File /usr/local/lib/python3.8/dist-packages/networkx/algorithms/shortest_paths/unweighted.py:221, in bidirectional_shortest_path(G, source, target)
#     219 if source not in G or target not in G:
#     220     msg = f"Either source {source} or target {target} is not in G"
# --> 221     raise nx.NodeNotFound(msg)
#     223 # call helper to do the real work
#     224 results = _bidirectional_pred_succ(G, source, target)
#
# NodeNotFound: Either source (1, 3) or target (2, 1) is not in G

# %% [markdown]
# Get the edges from this sequence of nodes:

# %%
zip(path[1:], path[:-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 zip(path[1:], path[:-1])
#
# NameError: name 'path' is not defined

# %%
edges = list(zip(path[1:],path[:-1]))
for a, b in edges:
    print('edge from %s to %s' % (a,b ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 edges = list(zip(path[1:],path[:-1]))
#       2 for a, b in edges:
#       3     print('edge from %s to %s' % (a,b ))
#
# NameError: name 'path' is not defined

# %% [markdown]
# We can recover the relative pose using `get_edge_data`:

# %%
deltas = []
for a, b in edges:
    R = M.get_edge_data(a, b)[0]['relative_pose']
    deltas.append(R)
    print('edge %s to %s: relative pose: %s' % (a, b, geo.SE2.friendly(R)))
print(deltas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 deltas = []
#       2 for a, b in edges:
# ----> 3     R = M.get_edge_data(a, b)[0]['relative_pose']
#       4     deltas.append(R)
#       5     print('edge %s to %s: relative pose: %s' % (a, b, geo.SE2.friendly(R)))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def multiply_deltas(G, deltas):
    S = geo.SE2.identity()
    for R in deltas:
        S = geo.SE2.multiply(S, R) # multiply on the right 
    return S

# %%
S = multiply_deltas(M, deltas)
print(geo.SE2.friendly(S))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 S = multiply_deltas(M, deltas)
#       2 print(geo.SE2.friendly(S))
#
# Cell In[57], line 2, in multiply_deltas(G, deltas)
#       1 def multiply_deltas(G, deltas):
# ----> 2     S = geo.SE2.identity()
#       3     for R in deltas:
#       4         S = geo.SE2.multiply(S, R) # multiply on the right
#
# NameError: name 'geo' is not defined

# %% [markdown]
# Now proceed to the [planning exercise](planning02.ipynb).

# %%
# import numpy as np

# np.degrees(np.arctan2(-1,-1))
# Out:
# -135.0

# %%
# a = np.array([1,2])
# c,b = a
# print(c,"\n\n",b)
# Out:
# 1
#
#  2

# %%
# pose_at_w = np.array([[0],[0]])
# r_cuvr = 2
# c_local_ctcw = np.array([[0],[r_cuvr]])
# c_local_cw = np.array([[0],[-r_cuvr]])
# theta_deg = 90

# thera_r = np.radians(theta_deg)
# c, s = np.cos(thera_r), np.sin(thera_r)
# R = np.array(((c, -s), (s, c)))
# # wp = c + R@lp
# c_ctcw = (pose_at_w + R@c_local_ctcw).flatten()
# c_cw = (pose_at_w + R@c_local_cw).flatten()
# print(c_ctcw, c_cw)
# Out:
# [-2.0000000e+00  1.2246468e-16] [ 2.0000000e+00 -1.2246468e-16]

# %%
# # a = True
# # b = False
# # if b or not a:
# #     print(3)

# d = {}
# d["a"] =1
# len(d)
# Out:
# 1

# %%
# import numpy as np
# np.degrees(np.arctan2(1,0))

# if
# Out:
# 90.0
